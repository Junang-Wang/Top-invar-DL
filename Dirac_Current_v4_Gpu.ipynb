# %% [markdown]
# A overview of the project:
#
# - [ ] Step1: Generate order parameters maps and supercurrent maps.
# - [ ] Step2: Construct machine learning model architecture
# - [ ] Step3: Train the model
# - [ ] Step4: Test the model

# %% [markdown]
# ## Step1: Generate order parameters and super current maps
#
# We consider the simplest model first:
# \begin{equation}
#    \hat{h} = \left( a k_x + i b k_y \right)^n \hat{\sigma}_+ + \left( a k_x - ib k_y \right)^n \hat{\sigma}_-
# \end{equation}

# %%
# %reload_ext autoreload
# %autoreload 2
from google.colab import drive
drive.mount('/content/drive')
import os
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'My_AI4Top/Top-invar-DL'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(GOOGLE_DRIVE_PATH)
import sys
sys.path.append(GOOGLE_DRIVE_PATH)
import torch
if torch.cuda.is_available:
  device = 'cuda'
  print('Good to go')
else:
  device = 'cpu'
  print('Please set GPU via Edit -> Notebook Settings')
# Out:
# Mounted at /content/drive
# drive/My Drive/My_AI4Top/Top-invar-DL
# Good to go

# %%
import numpy as np
import pandas as pd
from Dirac_Current import *
import functools
import time

# %% [markdown]
# We use following expressions for computing the superfluid stiffness of above continuous model. The total superfluid stiffness is given by
# \begin{equation}
#      D_{xx} = 2 \Delta^2 \int^{\pi}_{-\pi} \frac{dk_x}{2 \pi} \frac{dk_y}{2 \pi} \sum_{\alpha,\beta} \frac{\left\vert \langle u_{\alpha} \left\vert \partial_{k_x} \hat{h} \right\vert u_{\beta} ⟩  \right\vert^2}{E^2_{\alpha} - E^2_{\beta}} \left[ \frac{f_\beta}{E_\beta} - \frac{f_\alpha}{E_\alpha} \right],
# \end{equation}
# which contain two components: the intra-band contribution
#
# $$D_{\textrm{intra}} = \frac{a}{b} n \frac{\sqrt{\mu^2+\Delta^2}}{2\pi}\Bigg\{ \Theta(|\Delta|-|B|)+\Theta(|B|-|\Delta|)\Theta(\sqrt{\mu^2+\Delta^2}-|B|) \bigg[1-\frac{|\mu|}{\sqrt{\mu^2+\Delta^2}}\frac{|B|}{\sqrt{B^2-\Delta^2}}\bigg]\Bigg\}$$
#
# and the inter-band contribution
# $$D_{\textrm{inter}} = \frac{a}{b} n \frac{|\Delta|}{2\pi}\frac{|\Delta|}{|\mu|} \Bigg\{ \Theta(|\Delta|-|B|)\ln(\frac{\sqrt{\mu^2+\Delta^2}+|\mu|}{|\Delta|})+\Theta(|B|-|\Delta|)\Theta(\sqrt{\mu^2+\Delta^2}-|B|)\ln(\frac{\sqrt{\mu^2+\Delta^2}+|\mu|}{\sqrt{B^2-\Delta^2}+|B|}) \Bigg\}$$
# when $\mu \to 0$, $D_{\textrm{inter}}=\frac{a}{b}n\frac{|\Delta|}{2\pi}\Theta(|\Delta|-|B|) $

# %% [markdown]
# where $ \left\vert \overline{k}  \right\vert = \sqrt{a^2 k_x^2 + b^2 k_y^2}   $, $ E_{\pm} = \sqrt{(\left\vert \overline{k}   \right\vert^n \pm \mu )^2 + \Delta^2}  $, $ f(E) = \Theta(B+E)-\Theta(B-E)  $

# %%
print(Graphene_D.shape)
# Out:
# torch.Size([4141, 1, 15, 15])

# %%
# %%time
from Dirac_model_analytic import *
from Superfluid_Neural_network_v2 import *
from Training_loops import *
#torch.set_printoptions(sci_mode=False)
device = 'cuda'
B_steps = 15
mu_steps = 15

winding_array = torch.arange(1,10)
# winding_array = torch.arange(1,2)
winding_u = winding_array.shape[0]
Delta = torch.ones(1)
a_div_b = 1
B = torch.linspace(-2,2,steps=B_steps)
mu_offset_array = torch.linspace(-2,2,steps=mu_steps)
num_samples = torch.arange(51,502,50)
# num_samples = [51]
stats = 1
acc_test = torch.zeros(stats,len(num_samples))
acc_test_unseen = torch.zeros(stats,len(num_samples))
acc_graphene = torch.zeros(stats,len(num_samples))
N_train = torch.zeros(len(num_samples))
#-------------- density of acc ------------------------
bins = 15
bin_range = (-5,5)
acc_test_density = torch.zeros(stats,len(num_samples),bins)
acc_test_unseen_density = torch.zeros(stats,len(num_samples),bins)
acc_graphene_density = torch.zeros(stats,len(num_samples),bins)
###############################################################
# Set up neural network
###############################################################
num_class = 8
CNN_stages = [(1,32,1),(32,2,1)]
fc_stages = [(CNN_stages[-1][1]*B_steps*mu_steps,1024,1),(1024,512,1)]
my_vgg = NN_net(CNN_stages,fc_stages,Plain_CNN_block,Plain_fc_block,num_classes=num_class)
# optimizer parameters
epochs = 50
learning_rate_decay = .1
learning_rates = [1e-3]
weight_decays = [0]
acc_dict = {}
schedule = []
training_w = torch.tensor([0,1,2,3,4,5,6,7])
unseen_w = torch.tensor([8,9])

###################################################
# import graphene data
###################################################
Graphene_D_path = os.path.join(GOOGLE_DRIVE_PATH,'Graphene_D.pt')
Graphene_label_path = os.path.join(GOOGLE_DRIVE_PATH,'Graphene_label.pt')
Graphene_D = torch.load(Graphene_D_path)
Graphene_labels = torch.load(Graphene_label_path)
t_unique = 41
mu_random = 101
mu0_labels = torch.linspace(-5,5,mu_random).repeat(t_unique)
batch_size = 50
Graphene_Data = Superfluid_mu0_Dataset(Graphene_D,Graphene_labels,mu0_labels)
Graphene_loader = torch.utils.data.DataLoader(dataset=Graphene_Data,batch_size=batch_size,shuffle=True)
##################################################
#Compute Superfluid stiffness for each truck
#################################################
for i in range(stats):
  for j,n in enumerate(num_samples):
      mu0 = torch.linspace(-5,5,n)
      mu_random = mu0.shape[0]
      D_generator = Analytic_D(winding_array,mu0,mu_offset_array,B,device=device)
      D_total = D_generator.total().to(device='cpu')
      D_total_trivial = D_generator.trivial().to(device='cpu')
      torch.cuda.empty_cache()

      label_mask = (abs(mu0)<=2).repeat(winding_u,1).reshape(-1,1)
      labels = label_mask*(winding_array.repeat_interleave(mu_random).reshape(-1,1))
      labels_trivial = torch.zeros(1,mu_random).reshape(-1,1)


      D_total = (torch.pi/Delta)**2*torch.cat((D_total_trivial,D_total),dim=0)
      labels = torch.cat((labels_trivial,labels),dim=0).reshape(winding_u+1,mu_random)
      #print(D_total.shape,labels.shape)
      '''
      Set up dataset for training
      '''
      # split dataset to training and unseen data
      D_unseen = D_total[unseen_w].reshape(-1,1,mu_steps,B_steps) # the last two winding numbers as unseen data
      D_train = D_total[training_w].reshape(-1,1,mu_steps,B_steps)
      # set up labels 0-6 for training winding numbers, 7 for winding numbers above 6
      labels[labels>6] =7
      labels = labels.long()
      label_unseen = labels[unseen_w].reshape(-1)
      label_training = labels[training_w].reshape(-1)
      ##############################################################
      #set up dataset to train
      ##############################################################

      batch_size = 100
      #construct dataset
      dataset = Superfluid_Dataset(D_train,label_training,train=True) # train the model with the train data
      dataset_unseen = Superfluid_Dataset(D_unseen,label_unseen,train=True)

      # split the dataset to train, validation, test
      train_set, valid_set,test_set = torch.utils.data.random_split(dataset, [0.7,0.2,0.1])

      #Using Dataloader for batch train
      train_loader = torch.utils.data.DataLoader(dataset=train_set,batch_size=batch_size,shuffle=True)
      valid_loader = torch.utils.data.DataLoader(dataset=valid_set,batch_size=batch_size,shuffle=True)
      test_loader = torch.utils.data.DataLoader(dataset=test_set,batch_size=batch_size,shuffle=True)
      test_loader_unseen = torch.utils.data.DataLoader(dataset=dataset_unseen,batch_size=batch_size,shuffle=True)

      #############################################################
      # Train the neural network
      #############################################################


      for learning_rate in learning_rates:
          for weight_decay in weight_decays:
              my_vgg.apply(weight_init)
              L1_weight_decay = 0
              optimizer = torch.optim.Adam([{'params':my_vgg.parameters()}],lr=learning_rate,weight_decay=weight_decay)

              acc_history,acc_val_history,loss_history,iter_history = train_part(model=my_vgg,optimizer=optimizer,
              train_loader=train_loader,valid_loader=valid_loader,epochs=epochs,learning_rate_decay=learning_rate_decay,schedule=schedule,weight_decay=L1_weight_decay,verbose=False)
              ##############################################################
              print('weight_decay: ',weight_decay)
              N_train[j] = label_training.shape[0]
              print('number of training:', N_train[j])
              print('seen data acc: ')
              acc_test[i][j]= check_accuary(test_loader,my_vgg)
              print('unseen data acc:')
              acc_test_unseen[i][j] = check_accuary(test_loader_unseen,my_vgg)
              print('graphene data acc:')
              acc_graphene[i][j],acc_graphene_density[i][j]= check_accuary_density(Graphene_loader,my_vgg,bins=bins,range=bin_range)
# Out:
# Epoch 0, Iteration 3, loss = 32.4643
# Got 50 / 82 correct 0.61
# Got 189 / 286 correct 0.66
#
# Epoch 1, Iteration 6, loss = 10.1159
# Got 49 / 82 correct 0.60
# Got 185 / 286 correct 0.65
#
# Epoch 2, Iteration 9, loss = 7.0442
# Got 52 / 82 correct 0.63
# Got 196 / 286 correct 0.69
#
# Epoch 3, Iteration 12, loss = 2.3641
# Got 51 / 82 correct 0.62
# Got 198 / 286 correct 0.69
#
# Epoch 4, Iteration 15, loss = 1.5777
# Got 53 / 82 correct 0.65
# Got 199 / 286 correct 0.70
#
# Epoch 5, Iteration 18, loss = 1.3876
# Got 51 / 82 correct 0.62
# Got 196 / 286 correct 0.69
#
# Epoch 6, Iteration 21, loss = 1.3456
# Got 47 / 82 correct 0.57
# Got 189 / 286 correct 0.66
#
# Epoch 7, Iteration 24, loss = 1.3405
# Got 49 / 82 correct 0.60
# Got 192 / 286 correct 0.67
#
# Epoch 8, Iteration 27, loss = 1.0298
# Got 51 / 82 correct 0.62
# Got 194 / 286 correct 0.68
#
# Epoch 9, Iteration 30, loss = 1.1347
# Got 50 / 82 correct 0.61
# Got 195 / 286 correct 0.68
#
# Epoch 10, Iteration 33, loss = 1.1791
# Got 53 / 82 correct 0.65
# Got 198 / 286 correct 0.69
#
# Epoch 11, Iteration 36, loss = 0.9641
# Got 54 / 82 correct 0.66
# Got 199 / 286 correct 0.70
#
# Epoch 12, Iteration 39, loss = 0.6794
# Got 54 / 82 correct 0.66
# Got 199 / 286 correct 0.70
#
# Epoch 13, Iteration 42, loss = 0.8922
# Got 54 / 82 correct 0.66
# Got 202 / 286 correct 0.71
#
# Epoch 14, Iteration 45, loss = 0.5395
# Got 53 / 82 correct 0.65
# Got 203 / 286 correct 0.71
#
# Epoch 15, Iteration 48, loss = 0.7350
# Got 54 / 82 correct 0.66
# Got 201 / 286 correct 0.70
#
# Epoch 16, Iteration 51, loss = 0.4965
# Got 54 / 82 correct 0.66
# Got 210 / 286 correct 0.73
#
# Epoch 17, Iteration 54, loss = 0.5517
# Got 55 / 82 correct 0.67
# Got 223 / 286 correct 0.78
#
# Epoch 18, Iteration 57, loss = 0.5025
# Got 60 / 82 correct 0.73
# Got 235 / 286 correct 0.82
#
# Epoch 19, Iteration 60, loss = 0.4292
# Got 60 / 82 correct 0.73
# Got 237 / 286 correct 0.83
#
# Epoch 20, Iteration 63, loss = 0.5248
# Got 64 / 82 correct 0.78
# Got 243 / 286 correct 0.85
#
# Epoch 21, Iteration 66, loss = 0.3617
# Got 64 / 82 correct 0.78
# Got 246 / 286 correct 0.86
#
# Epoch 22, Iteration 69, loss = 0.3646
# Got 64 / 82 correct 0.78
# Got 251 / 286 correct 0.88
#
# Epoch 23, Iteration 72, loss = 0.3220
# Got 68 / 82 correct 0.83
# Got 262 / 286 correct 0.92
#
# Epoch 24, Iteration 75, loss = 0.2394
# Got 73 / 82 correct 0.89
# Got 273 / 286 correct 0.95
#
# Epoch 25, Iteration 78, loss = 0.2790
# Got 69 / 82 correct 0.84
# Got 268 / 286 correct 0.94
#
# Epoch 26, Iteration 81, loss = 0.2332
# Got 75 / 82 correct 0.91
# Got 273 / 286 correct 0.95
#
# Epoch 27, Iteration 84, loss = 0.2056
# Got 73 / 82 correct 0.89
# Got 275 / 286 correct 0.96
#
# Epoch 28, Iteration 87, loss = 0.1770
# Got 76 / 82 correct 0.93
# Got 275 / 286 correct 0.96
#
# Epoch 29, Iteration 90, loss = 0.1389
# Got 76 / 82 correct 0.93
# Got 274 / 286 correct 0.96
#
# Epoch 30, Iteration 93, loss = 0.1612
# Got 77 / 82 correct 0.94
# Got 282 / 286 correct 0.99
#
# Epoch 31, Iteration 96, loss = 0.1326
# Got 80 / 82 correct 0.98
# Got 284 / 286 correct 0.99
#
# Epoch 32, Iteration 99, loss = 0.0902
# Got 80 / 82 correct 0.98
# Got 284 / 286 correct 0.99
#
# Epoch 33, Iteration 102, loss = 0.0863
# Got 79 / 82 correct 0.96
# Got 285 / 286 correct 1.00
#
# Epoch 34, Iteration 105, loss = 0.0957
# Got 82 / 82 correct 1.00
# Got 283 / 286 correct 0.99
#
# Epoch 35, Iteration 108, loss = 0.1110
# Got 82 / 82 correct 1.00
# Got 283 / 286 correct 0.99
#
# Epoch 36, Iteration 111, loss = 0.0702
# Got 79 / 82 correct 0.96
# Got 284 / 286 correct 0.99
#
# Epoch 37, Iteration 114, loss = 0.0619
# Got 80 / 82 correct 0.98
# Got 283 / 286 correct 0.99
#
# Epoch 38, Iteration 117, loss = 0.1193
# Got 81 / 82 correct 0.99
# Got 283 / 286 correct 0.99
#
# Epoch 39, Iteration 120, loss = 0.1363
# Got 78 / 82 correct 0.95
# Got 275 / 286 correct 0.96
#
# lr decay from 0.001 to 0.0001
# 0.10 >= 0.09
# Epoch 40, Iteration 123, loss = 0.0454
# Got 80 / 82 correct 0.98
# Got 283 / 286 correct 0.99
#
# Epoch 41, Iteration 126, loss = 0.0306
# Got 82 / 82 correct 1.00
# Got 286 / 286 correct 1.00
#
# Epoch 42, Iteration 129, loss = 0.0390
# Got 82 / 82 correct 1.00
# Got 286 / 286 correct 1.00
#
# Epoch 43, Iteration 132, loss = 0.0368
# Got 82 / 82 correct 1.00
# Got 285 / 286 correct 1.00
#
# Epoch 44, Iteration 135, loss = 0.0370
# Got 82 / 82 correct 1.00
# Got 286 / 286 correct 1.00
#
# Epoch 45, Iteration 138, loss = 0.0421
# Got 82 / 82 correct 1.00
# Got 286 / 286 correct 1.00
#
# Epoch 46, Iteration 141, loss = 0.0315
# Got 82 / 82 correct 1.00
# Got 286 / 286 correct 1.00
#
# Epoch 47, Iteration 144, loss = 0.0368
# Got 80 / 82 correct 0.98
# Got 286 / 286 correct 1.00
#
# lr decay from 0.0001 to 1e-05
# 0.04 >= 0.04
# Epoch 48, Iteration 147, loss = 0.0467
# Got 80 / 82 correct 0.98
# Got 286 / 286 correct 1.00
#
# Epoch 49, Iteration 150, loss = 0.0273
# Got 80 / 82 correct 0.98
# Got 286 / 286 correct 1.00
#
# weight_decay:  0
# number of training: tensor(408.)
# seen data acc:
# Got 36 / 40 correct 0.90
# unseen data acc:
# Got 98 / 102 correct 0.96
# graphene data acc:
# Got 3684 / 4141 correct 0.89
# Epoch 0, Iteration 6, loss = 207.5203
# Got 47 / 162 correct 0.29
# Got 230 / 566 correct 0.41
#
# Epoch 1, Iteration 12, loss = 111.4752
# Got 107 / 162 correct 0.66
# Got 363 / 566 correct 0.64
#
# Epoch 2, Iteration 18, loss = 44.6639
# Got 83 / 162 correct 0.51
# Got 314 / 566 correct 0.55
#
# Epoch 3, Iteration 24, loss = 33.3269
# Got 102 / 162 correct 0.63
# Got 379 / 566 correct 0.67
#
# Epoch 4, Iteration 30, loss = 18.0035
# Got 92 / 162 correct 0.57
# Got 343 / 566 correct 0.61
#
# Epoch 5, Iteration 36, loss = 8.5262
# Got 104 / 162 correct 0.64
# Got 374 / 566 correct 0.66
#
# Epoch 6, Iteration 42, loss = 6.8136
# Got 93 / 162 correct 0.57
# Got 331 / 566 correct 0.58
#
# Epoch 7, Iteration 48, loss = 2.3027
# Got 105 / 162 correct 0.65
# Got 377 / 566 correct 0.67
#
# Epoch 8, Iteration 54, loss = 2.6256
# Got 106 / 162 correct 0.65
# Got 378 / 566 correct 0.67
#
# Epoch 9, Iteration 60, loss = 2.3805
# Got 107 / 162 correct 0.66
# Got 368 / 566 correct 0.65
#
# Epoch 10, Iteration 66, loss = 1.0493
# Got 107 / 162 correct 0.66
# Got 384 / 566 correct 0.68
#
# Epoch 11, Iteration 72, loss = 0.8336
# Got 107 / 162 correct 0.66
# Got 382 / 566 correct 0.67
#
# Epoch 12, Iteration 78, loss = 1.6670
# Got 109 / 162 correct 0.67
# Got 387 / 566 correct 0.68
#
# Epoch 13, Iteration 84, loss = 1.1392
# Got 108 / 162 correct 0.67
# Got 385 / 566 correct 0.68
#
# Epoch 14, Iteration 90, loss = 1.0460
# Got 113 / 162 correct 0.70
# Got 397 / 566 correct 0.70
#
# Epoch 15, Iteration 96, loss = 0.8009
# Got 111 / 162 correct 0.69
# Got 405 / 566 correct 0.72
#
# Epoch 16, Iteration 102, loss = 1.2205
# Got 113 / 162 correct 0.70
# Got 418 / 566 correct 0.74
#
# Epoch 17, Iteration 108, loss = 0.9159
# Got 116 / 162 correct 0.72
# Got 427 / 566 correct 0.75
#
# Epoch 18, Iteration 114, loss = 1.3387
# Got 121 / 162 correct 0.75
# Got 406 / 566 correct 0.72
#
# lr decay from 0.001 to 0.0001
# 1.07 >= 1.11
# Epoch 19, Iteration 120, loss = 0.6221
# Got 113 / 162 correct 0.70
# Got 426 / 566 correct 0.75
#
# Epoch 20, Iteration 126, loss = 0.7202
# Got 111 / 162 correct 0.69
# Got 435 / 566 correct 0.77
#
# Epoch 21, Iteration 132, loss = 0.7552
# Got 115 / 162 correct 0.71
# Got 440 / 566 correct 0.78
#
# Epoch 22, Iteration 138, loss = 0.6198
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 23, Iteration 144, loss = 0.7421
# Got 113 / 162 correct 0.70
# Got 433 / 566 correct 0.77
#
# Epoch 24, Iteration 150, loss = 0.5519
# Got 113 / 162 correct 0.70
# Got 432 / 566 correct 0.76
#
# Epoch 25, Iteration 156, loss = 0.6038
# Got 112 / 162 correct 0.69
# Got 430 / 566 correct 0.76
#
# Epoch 26, Iteration 162, loss = 0.7657
# Got 111 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# lr decay from 0.0001 to 1e-05
# 0.67 >= 0.65
# Epoch 27, Iteration 168, loss = 0.6751
# Got 111 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 28, Iteration 174, loss = 0.4619
# Got 111 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 29, Iteration 180, loss = 0.8080
# Got 111 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 30, Iteration 186, loss = 0.6698
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# lr decay from 1e-05 to 1.0000000000000002e-06
# 0.65 >= 0.63
# Epoch 31, Iteration 192, loss = 0.6044
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 32, Iteration 198, loss = 0.5002
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 33, Iteration 204, loss = 0.6121
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 34, Iteration 210, loss = 0.6062
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 35, Iteration 216, loss = 0.3962
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 36, Iteration 222, loss = 0.6464
# Got 112 / 162 correct 0.69
# Got 433 / 566 correct 0.77
#
# Epoch 37, Iteration 228, loss = 0.6237
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# lr decay from 1.0000000000000002e-06 to 1.0000000000000002e-07
# 0.57 >= 0.57
# Epoch 38, Iteration 234, loss = 0.7702
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 39, Iteration 240, loss = 0.6576
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 40, Iteration 246, loss = 0.7739
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 41, Iteration 252, loss = 0.5129
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# lr decay from 1.0000000000000002e-07 to 1.0000000000000004e-08
# 0.68 >= 0.54
# Epoch 42, Iteration 258, loss = 0.6052
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 43, Iteration 264, loss = 0.7259
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 44, Iteration 270, loss = 0.5533
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 45, Iteration 276, loss = 0.8077
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# lr decay from 1.0000000000000004e-08 to 1.0000000000000005e-09
# 0.67 >= 0.64
# Epoch 46, Iteration 282, loss = 0.6325
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 47, Iteration 288, loss = 0.5250
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 48, Iteration 294, loss = 0.6285
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# Epoch 49, Iteration 300, loss = 0.5517
# Got 112 / 162 correct 0.69
# Got 434 / 566 correct 0.77
#
# weight_decay:  0
# number of training: tensor(808.)
# seen data acc:
# Got 58 / 80 correct 0.72
# unseen data acc:
# Got 182 / 202 correct 0.90
# graphene data acc:
# Got 2489 / 4141 correct 0.60
# Epoch 0, Iteration 9, loss = 3.5989
# Got 164 / 242 correct 0.68
# Got 584 / 846 correct 0.69
#
# Epoch 1, Iteration 18, loss = 1.3300
# Got 171 / 242 correct 0.71
# Got 594 / 846 correct 0.70
#
# Epoch 2, Iteration 27, loss = 0.9302
# Got 170 / 242 correct 0.70
# Got 585 / 846 correct 0.69
#
# Epoch 3, Iteration 36, loss = 0.8254
# Got 170 / 242 correct 0.70
# Got 595 / 846 correct 0.70
#
# Epoch 4, Iteration 45, loss = 0.6894
# Got 171 / 242 correct 0.71
# Got 599 / 846 correct 0.71
#
# Epoch 5, Iteration 54, loss = 0.6900
# Got 172 / 242 correct 0.71
# Got 600 / 846 correct 0.71
#
# Epoch 6, Iteration 63, loss = 0.5923
# Got 170 / 242 correct 0.70
# Got 612 / 846 correct 0.72
#
# Epoch 7, Iteration 72, loss = 0.5754
# Got 176 / 242 correct 0.73
# Got 624 / 846 correct 0.74
#
# Epoch 8, Iteration 81, loss = 0.8430
# Got 185 / 242 correct 0.76
# Got 666 / 846 correct 0.79
#
# Epoch 9, Iteration 90, loss = 0.5028
# Got 198 / 242 correct 0.82
# Got 719 / 846 correct 0.85
#
# Epoch 10, Iteration 99, loss = 0.4245
# Got 205 / 242 correct 0.85
# Got 731 / 846 correct 0.86
#
# Epoch 11, Iteration 108, loss = 0.3258
# Got 215 / 242 correct 0.89
# Got 768 / 846 correct 0.91
#
# Epoch 12, Iteration 117, loss = 0.4853
# Got 208 / 242 correct 0.86
# Got 736 / 846 correct 0.87
#
# Epoch 13, Iteration 126, loss = 0.2624
# Got 223 / 242 correct 0.92
# Got 784 / 846 correct 0.93
#
# Epoch 14, Iteration 135, loss = 0.3044
# Got 218 / 242 correct 0.90
# Got 772 / 846 correct 0.91
#
# Epoch 15, Iteration 144, loss = 0.4283
# Got 232 / 242 correct 0.96
# Got 820 / 846 correct 0.97
#
# Epoch 16, Iteration 153, loss = 0.1453
# Got 233 / 242 correct 0.96
# Got 799 / 846 correct 0.94
#
# Epoch 17, Iteration 162, loss = 0.2558
# Got 227 / 242 correct 0.94
# Got 798 / 846 correct 0.94
#
# Epoch 18, Iteration 171, loss = 0.2018
# Got 229 / 242 correct 0.95
# Got 803 / 846 correct 0.95
#
# Epoch 19, Iteration 180, loss = 0.1896
# Got 236 / 242 correct 0.98
# Got 823 / 846 correct 0.97
#
# Epoch 20, Iteration 189, loss = 0.2720
# Got 236 / 242 correct 0.98
# Got 829 / 846 correct 0.98
#
# Epoch 21, Iteration 198, loss = 0.1618
# Got 230 / 242 correct 0.95
# Got 796 / 846 correct 0.94
#
# Epoch 22, Iteration 207, loss = 0.1610
# Got 237 / 242 correct 0.98
# Got 839 / 846 correct 0.99
#
# Epoch 23, Iteration 216, loss = 0.0569
# Got 239 / 242 correct 0.99
# Got 835 / 846 correct 0.99
#
# Epoch 24, Iteration 225, loss = 0.0604
# Got 240 / 242 correct 0.99
# Got 841 / 846 correct 0.99
#
# Epoch 25, Iteration 234, loss = 0.0585
# Got 235 / 242 correct 0.97
# Got 834 / 846 correct 0.99
#
# Epoch 26, Iteration 243, loss = 0.0963
# Got 241 / 242 correct 1.00
# Got 838 / 846 correct 0.99
#
# Epoch 27, Iteration 252, loss = 0.0316
# Got 236 / 242 correct 0.98
# Got 840 / 846 correct 0.99
#
# Epoch 28, Iteration 261, loss = 0.0187
# Got 241 / 242 correct 1.00
# Got 843 / 846 correct 1.00
#
# Epoch 29, Iteration 270, loss = 0.0144
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# Epoch 30, Iteration 279, loss = 0.0749
# Got 240 / 242 correct 0.99
# Got 841 / 846 correct 0.99
#
# Epoch 31, Iteration 288, loss = 0.0435
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# Epoch 32, Iteration 297, loss = 0.0202
# Got 240 / 242 correct 0.99
# Got 846 / 846 correct 1.00
#
# Epoch 33, Iteration 306, loss = 0.0143
# Got 241 / 242 correct 1.00
# Got 844 / 846 correct 1.00
#
# lr decay from 0.001 to 0.0001
# 0.04 >= 0.04
# Epoch 34, Iteration 315, loss = 0.0368
# Got 241 / 242 correct 1.00
# Got 845 / 846 correct 1.00
#
# Epoch 35, Iteration 324, loss = 0.0112
# Got 240 / 242 correct 0.99
# Got 846 / 846 correct 1.00
#
# Epoch 36, Iteration 333, loss = 0.0109
# Got 240 / 242 correct 0.99
# Got 845 / 846 correct 1.00
#
# Epoch 37, Iteration 342, loss = 0.0086
# Got 240 / 242 correct 0.99
# Got 846 / 846 correct 1.00
#
# Epoch 38, Iteration 351, loss = 0.0133
# Got 240 / 242 correct 0.99
# Got 846 / 846 correct 1.00
#
# Epoch 39, Iteration 360, loss = 0.0125
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# Epoch 40, Iteration 369, loss = 0.0028
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# Epoch 41, Iteration 378, loss = 0.0071
# Got 240 / 242 correct 0.99
# Got 846 / 846 correct 1.00
#
# Epoch 42, Iteration 387, loss = 0.0072
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# Epoch 43, Iteration 396, loss = 0.0062
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# Epoch 44, Iteration 405, loss = 0.0091
# Got 240 / 242 correct 0.99
# Got 846 / 846 correct 1.00
#
# Epoch 45, Iteration 414, loss = 0.0076
# Got 240 / 242 correct 0.99
# Got 846 / 846 correct 1.00
#
# Epoch 46, Iteration 423, loss = 0.0065
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# lr decay from 0.0001 to 1e-05
# 0.01 >= 0.01
# Epoch 47, Iteration 432, loss = 0.0144
# Got 241 / 242 correct 1.00
# Got 846 / 846 correct 1.00
#
# acc_val reachs to 100%, end the training loop
# weight_decay:  0
# number of training: tensor(1208.)
# seen data acc:
# Got 120 / 120 correct 1.00
# unseen data acc:
# Got 298 / 302 correct 0.99
# graphene data acc:
# Got 4015 / 4141 correct 0.97
# Epoch 0, Iteration 12, loss = 2.9897
# Got 233 / 322 correct 0.72
# Got 775 / 1126 correct 0.69
#
# Epoch 1, Iteration 24, loss = 1.6544
# Got 227 / 322 correct 0.70
# Got 780 / 1126 correct 0.69
#
# Epoch 2, Iteration 36, loss = 2.3296
# Got 229 / 322 correct 0.71
# Got 784 / 1126 correct 0.70
#
# Epoch 3, Iteration 48, loss = 0.5749
# Got 227 / 322 correct 0.70
# Got 779 / 1126 correct 0.69
#
# Epoch 4, Iteration 60, loss = 0.4494
# Got 232 / 322 correct 0.72
# Got 802 / 1126 correct 0.71
#
# Epoch 5, Iteration 72, loss = 0.7023
# Got 231 / 322 correct 0.72
# Got 829 / 1126 correct 0.74
#
# Epoch 6, Iteration 84, loss = 0.6316
# Got 250 / 322 correct 0.78
# Got 880 / 1126 correct 0.78
#
# Epoch 7, Iteration 96, loss = 0.7849
# Got 270 / 322 correct 0.84
# Got 936 / 1126 correct 0.83
#
# Epoch 8, Iteration 108, loss = 0.7125
# Got 267 / 322 correct 0.83
# Got 940 / 1126 correct 0.83
#
# Epoch 9, Iteration 120, loss = 0.4759
# Got 278 / 322 correct 0.86
# Got 972 / 1126 correct 0.86
#
# Epoch 10, Iteration 132, loss = 0.2434
# Got 293 / 322 correct 0.91
# Got 1030 / 1126 correct 0.91
#
# lr decay from 0.001 to 0.0001
# 0.55 >= 0.56
# Epoch 11, Iteration 144, loss = 0.0998
# Got 299 / 322 correct 0.93
# Got 1077 / 1126 correct 0.96
#
# Epoch 12, Iteration 156, loss = 0.1007
# Got 303 / 322 correct 0.94
# Got 1065 / 1126 correct 0.95
#
# Epoch 13, Iteration 168, loss = 0.2171
# Got 308 / 322 correct 0.96
# Got 1092 / 1126 correct 0.97
#
# Epoch 14, Iteration 180, loss = 0.1738
# Got 309 / 322 correct 0.96
# Got 1086 / 1126 correct 0.96
#
# Epoch 15, Iteration 192, loss = 0.0820
# Got 310 / 322 correct 0.96
# Got 1103 / 1126 correct 0.98
#
# Epoch 16, Iteration 204, loss = 0.1317
# Got 309 / 322 correct 0.96
# Got 1095 / 1126 correct 0.97
#
# Epoch 17, Iteration 216, loss = 0.2423
# Got 308 / 322 correct 0.96
# Got 1092 / 1126 correct 0.97
#
# lr decay from 0.0001 to 1e-05
# 0.16 >= 0.16
# Epoch 18, Iteration 228, loss = 0.2602
# Got 309 / 322 correct 0.96
# Got 1096 / 1126 correct 0.97
#
# Epoch 19, Iteration 240, loss = 0.1393
# Got 309 / 322 correct 0.96
# Got 1098 / 1126 correct 0.98
#
# Epoch 20, Iteration 252, loss = 0.2941
# Got 309 / 322 correct 0.96
# Got 1098 / 1126 correct 0.98
#
# Epoch 21, Iteration 264, loss = 0.1441
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# lr decay from 1e-05 to 1.0000000000000002e-06
# 0.21 >= 0.15
# Epoch 22, Iteration 276, loss = 0.2637
# Got 308 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 23, Iteration 288, loss = 0.1289
# Got 308 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 24, Iteration 300, loss = 0.2293
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 25, Iteration 312, loss = 0.1598
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# lr decay from 1.0000000000000002e-06 to 1.0000000000000002e-07
# 0.20 >= 0.20
# Epoch 26, Iteration 324, loss = 0.1964
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 27, Iteration 336, loss = 0.3434
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 28, Iteration 348, loss = 0.1896
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 29, Iteration 360, loss = 0.1237
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# lr decay from 1.0000000000000002e-07 to 1.0000000000000004e-08
# 0.21 >= 0.19
# Epoch 30, Iteration 372, loss = 0.1502
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 31, Iteration 384, loss = 0.1048
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 32, Iteration 396, loss = 0.2184
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 33, Iteration 408, loss = 0.0998
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 34, Iteration 420, loss = 0.1921
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 35, Iteration 432, loss = 0.0763
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# lr decay from 1.0000000000000004e-08 to 1.0000000000000005e-09
# 0.15 >= 0.13
# Epoch 36, Iteration 444, loss = 0.3131
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 37, Iteration 456, loss = 0.1765
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 38, Iteration 468, loss = 0.2407
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 39, Iteration 480, loss = 0.1602
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# lr decay from 1.0000000000000005e-09 to 1.0000000000000006e-10
# 0.22 >= 0.14
# Epoch 40, Iteration 492, loss = 0.2310
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 41, Iteration 504, loss = 0.2098
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 42, Iteration 516, loss = 0.2702
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 43, Iteration 528, loss = 0.2591
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# lr decay from 1.0000000000000006e-10 to 1.0000000000000006e-11
# 0.24 >= 0.21
# Epoch 44, Iteration 540, loss = 0.2129
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 45, Iteration 552, loss = 0.3850
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 46, Iteration 564, loss = 0.1731
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 47, Iteration 576, loss = 0.1455
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# lr decay from 1.0000000000000006e-11 to 1.0000000000000006e-12
# 0.23 >= 0.23
# Epoch 48, Iteration 588, loss = 0.2041
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# Epoch 49, Iteration 600, loss = 0.1059
# Got 309 / 322 correct 0.96
# Got 1100 / 1126 correct 0.98
#
# weight_decay:  0
# number of training: tensor(1608.)
# seen data acc:
# Got 145 / 160 correct 0.91
# unseen data acc:
# Got 401 / 402 correct 1.00
# graphene data acc:
# Got 3769 / 4141 correct 0.91
# Epoch 0, Iteration 15, loss = 2.4634
# Got 254 / 402 correct 0.63
# Got 865 / 1406 correct 0.62
#
# Epoch 1, Iteration 30, loss = 0.9187
# Got 277 / 402 correct 0.69
# Got 977 / 1406 correct 0.69
#
# Epoch 2, Iteration 45, loss = 0.5064
# Got 274 / 402 correct 0.68
# Got 983 / 1406 correct 0.70
#
# Epoch 3, Iteration 60, loss = 0.5990
# Got 274 / 402 correct 0.68
# Got 987 / 1406 correct 0.70
#
# Epoch 4, Iteration 75, loss = 0.9968
# Got 282 / 402 correct 0.70
# Got 1042 / 1406 correct 0.74
#
# Epoch 5, Iteration 90, loss = 0.2802
# Got 294 / 402 correct 0.73
# Got 1088 / 1406 correct 0.77
#
# Epoch 6, Iteration 105, loss = 0.9260
# Got 305 / 402 correct 0.76
# Got 1102 / 1406 correct 0.78
#
# Epoch 7, Iteration 120, loss = 0.5764
# Got 316 / 402 correct 0.79
# Got 1132 / 1406 correct 0.81
#
# Epoch 8, Iteration 135, loss = 0.2975
# Got 324 / 402 correct 0.81
# Got 1163 / 1406 correct 0.83
#
# Epoch 9, Iteration 150, loss = 1.6309
# Got 336 / 402 correct 0.84
# Got 1202 / 1406 correct 0.85
#
# lr decay from 0.001 to 0.0001
# 0.86 >= 0.57
# Epoch 10, Iteration 165, loss = 0.5956
# Got 341 / 402 correct 0.85
# Got 1213 / 1406 correct 0.86
#
# Epoch 11, Iteration 180, loss = 0.2952
# Got 341 / 402 correct 0.85
# Got 1237 / 1406 correct 0.88
#
# Epoch 12, Iteration 195, loss = 0.3652
# Got 339 / 402 correct 0.84
# Got 1228 / 1406 correct 0.87
#
# Epoch 13, Iteration 210, loss = 0.1260
# Got 338 / 402 correct 0.84
# Got 1219 / 1406 correct 0.87
#
# Epoch 14, Iteration 225, loss = 0.2994
# Got 342 / 402 correct 0.85
# Got 1228 / 1406 correct 0.87
#
# Epoch 15, Iteration 240, loss = 0.0915
# Got 347 / 402 correct 0.86
# Got 1241 / 1406 correct 0.88
#
# Epoch 16, Iteration 255, loss = 0.1251
# Got 346 / 402 correct 0.86
# Got 1254 / 1406 correct 0.89
#
# Epoch 17, Iteration 270, loss = 0.1869
# Got 351 / 402 correct 0.87
# Got 1259 / 1406 correct 0.90
#
# Epoch 18, Iteration 285, loss = 0.3395
# Got 350 / 402 correct 0.87
# Got 1258 / 1406 correct 0.89
#
# Epoch 19, Iteration 300, loss = 0.6897
# Got 356 / 402 correct 0.89
# Got 1286 / 1406 correct 0.91
#
# lr decay from 0.0001 to 1e-05
# 0.34 >= 0.21
# Epoch 20, Iteration 315, loss = 0.2276
# Got 355 / 402 correct 0.88
# Got 1288 / 1406 correct 0.92
#
# Epoch 21, Iteration 330, loss = 0.5757
# Got 355 / 402 correct 0.88
# Got 1289 / 1406 correct 0.92
#
# Epoch 22, Iteration 345, loss = 0.2071
# Got 356 / 402 correct 0.89
# Got 1288 / 1406 correct 0.92
#
# Epoch 23, Iteration 360, loss = 0.1166
# Got 358 / 402 correct 0.89
# Got 1287 / 1406 correct 0.92
#
# Epoch 24, Iteration 375, loss = 0.6779
# Got 357 / 402 correct 0.89
# Got 1282 / 1406 correct 0.91
#
# lr decay from 1e-05 to 1.0000000000000002e-06
# 0.39 >= 0.34
# Epoch 25, Iteration 390, loss = 0.3180
# Got 357 / 402 correct 0.89
# Got 1282 / 1406 correct 0.91
#
# Epoch 26, Iteration 405, loss = 0.1848
# Got 357 / 402 correct 0.89
# Got 1282 / 1406 correct 0.91
#
# Epoch 27, Iteration 420, loss = 0.0121
# Got 357 / 402 correct 0.89
# Got 1282 / 1406 correct 0.91
#
# Epoch 28, Iteration 435, loss = 0.6113
# Got 357 / 402 correct 0.89
# Got 1282 / 1406 correct 0.91
#
# Epoch 29, Iteration 450, loss = 0.6707
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# lr decay from 1.0000000000000002e-06 to 1.0000000000000002e-07
# 0.37 >= 0.31
# Epoch 30, Iteration 465, loss = 0.6080
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 31, Iteration 480, loss = 0.4332
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 32, Iteration 495, loss = 0.0674
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 33, Iteration 510, loss = 0.5894
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# lr decay from 1.0000000000000002e-07 to 1.0000000000000004e-08
# 0.42 >= 0.35
# Epoch 34, Iteration 525, loss = 0.5194
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 35, Iteration 540, loss = 0.6053
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 36, Iteration 555, loss = 0.0103
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 37, Iteration 570, loss = 0.4023
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# lr decay from 1.0000000000000004e-08 to 1.0000000000000005e-09
# 0.38 >= 0.40
# Epoch 38, Iteration 585, loss = 0.3323
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 39, Iteration 600, loss = 0.3112
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 40, Iteration 615, loss = 0.5693
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 41, Iteration 630, loss = 0.4953
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# lr decay from 1.0000000000000005e-09 to 1.0000000000000006e-10
# 0.43 >= 0.37
# Epoch 42, Iteration 645, loss = 0.0882
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 43, Iteration 660, loss = 0.4977
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 44, Iteration 675, loss = 0.2305
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 45, Iteration 690, loss = 0.1600
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 46, Iteration 705, loss = 0.0062
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 47, Iteration 720, loss = 0.4378
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 48, Iteration 735, loss = 0.3101
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# Epoch 49, Iteration 750, loss = 0.2673
# Got 357 / 402 correct 0.89
# Got 1281 / 1406 correct 0.91
#
# lr decay from 1.0000000000000006e-10 to 1.0000000000000006e-11
# 0.26 >= 0.23
# weight_decay:  0
# number of training: tensor(2008.)
# seen data acc:
# Got 184 / 200 correct 0.92
# unseen data acc:
# Got 489 / 502 correct 0.97
# graphene data acc:
# Got 3982 / 4141 correct 0.96
# Epoch 0, Iteration 17, loss = 1.5757
# Got 343 / 482 correct 0.71
# Got 1141 / 1686 correct 0.68
#
# Epoch 1, Iteration 34, loss = 1.0159
# Got 342 / 482 correct 0.71
# Got 1139 / 1686 correct 0.68
#
# Epoch 2, Iteration 51, loss = 0.8755
# Got 347 / 482 correct 0.72
# Got 1164 / 1686 correct 0.69
#
# Epoch 3, Iteration 68, loss = 0.7263
# Got 351 / 482 correct 0.73
# Got 1169 / 1686 correct 0.69
#
# Epoch 4, Iteration 85, loss = 0.5710
# Got 359 / 482 correct 0.74
# Got 1228 / 1686 correct 0.73
#
# Epoch 5, Iteration 102, loss = 0.5377
# Got 392 / 482 correct 0.81
# Got 1375 / 1686 correct 0.82
#
# Epoch 6, Iteration 119, loss = 0.5454
# Got 411 / 482 correct 0.85
# Got 1438 / 1686 correct 0.85
#
# Epoch 7, Iteration 136, loss = 0.3279
# Got 447 / 482 correct 0.93
# Got 1576 / 1686 correct 0.93
#
# Epoch 8, Iteration 153, loss = 0.2812
# Got 447 / 482 correct 0.93
# Got 1531 / 1686 correct 0.91
#
# Epoch 9, Iteration 170, loss = 0.1308
# Got 476 / 482 correct 0.99
# Got 1660 / 1686 correct 0.98
#
# Epoch 10, Iteration 187, loss = 0.1054
# Got 471 / 482 correct 0.98
# Got 1651 / 1686 correct 0.98
#
# Epoch 11, Iteration 204, loss = 0.1058
# Got 478 / 482 correct 0.99
# Got 1676 / 1686 correct 0.99
#
# Epoch 12, Iteration 221, loss = 0.0336
# Got 468 / 482 correct 0.97
# Got 1653 / 1686 correct 0.98
#
# Epoch 13, Iteration 238, loss = 0.0273
# Got 475 / 482 correct 0.99
# Got 1670 / 1686 correct 0.99
#
# Epoch 14, Iteration 255, loss = 0.0562
# Got 474 / 482 correct 0.98
# Got 1668 / 1686 correct 0.99
#
# Epoch 15, Iteration 272, loss = 0.0338
# Got 477 / 482 correct 0.99
# Got 1677 / 1686 correct 0.99
#
# Epoch 16, Iteration 289, loss = 0.0288
# Got 479 / 482 correct 0.99
# Got 1679 / 1686 correct 1.00
#
# Epoch 17, Iteration 306, loss = 0.0298
# Got 475 / 482 correct 0.99
# Got 1673 / 1686 correct 0.99
#
# Epoch 18, Iteration 323, loss = 0.0158
# Got 479 / 482 correct 0.99
# Got 1678 / 1686 correct 1.00
#
# Epoch 19, Iteration 340, loss = 0.0360
# Got 475 / 482 correct 0.99
# Got 1667 / 1686 correct 0.99
#
# Epoch 20, Iteration 357, loss = 0.2569
# Got 473 / 482 correct 0.98
# Got 1648 / 1686 correct 0.98
#
# lr decay from 0.001 to 0.0001
# 0.08 >= 0.03
# Epoch 21, Iteration 374, loss = 0.0047
# Got 481 / 482 correct 1.00
# Got 1681 / 1686 correct 1.00
#
# acc_val reachs to 100%, end the training loop
# weight_decay:  0
# number of training: tensor(2408.)
# seen data acc:
# Got 240 / 240 correct 1.00
# unseen data acc:
# Got 597 / 602 correct 0.99
# graphene data acc:
# Got 4091 / 4141 correct 0.99
# Epoch 0, Iteration 20, loss = 2.6351
# Got 354 / 562 correct 0.63
# Got 1271 / 1966 correct 0.65
#
# Epoch 1, Iteration 40, loss = 1.0695
# Got 390 / 562 correct 0.69
# Got 1368 / 1966 correct 0.70
#
# Epoch 2, Iteration 60, loss = 0.7491
# Got 385 / 562 correct 0.69
# Got 1372 / 1966 correct 0.70
#
# Epoch 3, Iteration 80, loss = 0.6481
# Got 394 / 562 correct 0.70
# Got 1420 / 1966 correct 0.72
#
# Epoch 4, Iteration 100, loss = 0.5475
# Got 411 / 562 correct 0.73
# Got 1432 / 1966 correct 0.73
#
# Epoch 5, Iteration 120, loss = 0.4910
# Got 462 / 562 correct 0.82
# Got 1646 / 1966 correct 0.84
#
# Epoch 6, Iteration 140, loss = 0.4206
# Got 498 / 562 correct 0.89
# Got 1760 / 1966 correct 0.90
#
# Epoch 7, Iteration 160, loss = 0.3607
# Got 528 / 562 correct 0.94
# Got 1853 / 1966 correct 0.94
#
# Epoch 8, Iteration 180, loss = 0.2802
# Got 529 / 562 correct 0.94
# Got 1858 / 1966 correct 0.95
#
# Epoch 9, Iteration 200, loss = 0.2184
# Got 522 / 562 correct 0.93
# Got 1851 / 1966 correct 0.94
#
# Epoch 10, Iteration 220, loss = 0.1143
# Got 540 / 562 correct 0.96
# Got 1909 / 1966 correct 0.97
#
# Epoch 11, Iteration 240, loss = 0.0652
# Got 553 / 562 correct 0.98
# Got 1945 / 1966 correct 0.99
#
# Epoch 12, Iteration 260, loss = 0.0736
# Got 544 / 562 correct 0.97
# Got 1920 / 1966 correct 0.98
#
# Epoch 13, Iteration 280, loss = 0.0367
# Got 558 / 562 correct 0.99
# Got 1949 / 1966 correct 0.99
#
# Epoch 14, Iteration 300, loss = 0.0201
# Got 541 / 562 correct 0.96
# Got 1900 / 1966 correct 0.97
#
# Epoch 15, Iteration 320, loss = 0.0245
# Got 528 / 562 correct 0.94
# Got 1844 / 1966 correct 0.94
#
# Epoch 16, Iteration 340, loss = 0.0896
# Got 552 / 562 correct 0.98
# Got 1932 / 1966 correct 0.98
#
# Epoch 17, Iteration 360, loss = 0.0189
# Got 558 / 562 correct 0.99
# Got 1948 / 1966 correct 0.99
#
# Epoch 18, Iteration 380, loss = 0.0487
# Got 558 / 562 correct 0.99
# Got 1943 / 1966 correct 0.99
#
# lr decay from 0.001 to 0.0001
# 0.05 >= 0.05
# Epoch 19, Iteration 400, loss = 0.0231
# Got 559 / 562 correct 0.99
# Got 1961 / 1966 correct 1.00
#
# Epoch 20, Iteration 420, loss = 0.0085
# Got 561 / 562 correct 1.00
# Got 1963 / 1966 correct 1.00
#
# Epoch 21, Iteration 440, loss = 0.0084
# Got 558 / 562 correct 0.99
# Got 1962 / 1966 correct 1.00
#
# Epoch 22, Iteration 460, loss = 0.0193
# Got 560 / 562 correct 1.00
# Got 1965 / 1966 correct 1.00
#
# Epoch 23, Iteration 480, loss = 0.0044
# Got 560 / 562 correct 1.00
# Got 1965 / 1966 correct 1.00
#
# Epoch 24, Iteration 500, loss = 0.0064
# Got 560 / 562 correct 1.00
# Got 1965 / 1966 correct 1.00
#
# Epoch 25, Iteration 520, loss = 0.0126
# Got 560 / 562 correct 1.00
# Got 1964 / 1966 correct 1.00
#
# Epoch 26, Iteration 540, loss = 0.0141
# Got 560 / 562 correct 1.00
# Got 1964 / 1966 correct 1.00
#
# Epoch 27, Iteration 560, loss = 0.0098
# Got 559 / 562 correct 0.99
# Got 1965 / 1966 correct 1.00
#
# lr decay from 0.0001 to 1e-05
# 0.01 >= 0.01
# Epoch 28, Iteration 580, loss = 0.0072
# Got 559 / 562 correct 0.99
# Got 1965 / 1966 correct 1.00
#
# Epoch 29, Iteration 600, loss = 0.0112
# Got 560 / 562 correct 1.00
# Got 1965 / 1966 correct 1.00
#
# Epoch 30, Iteration 620, loss = 0.0191
# Got 561 / 562 correct 1.00
# Got 1965 / 1966 correct 1.00
#
# acc_val reachs to 100%, end the training loop
# weight_decay:  0
# number of training: tensor(2808.)
# seen data acc:
# Got 279 / 280 correct 1.00
# unseen data acc:
# Got 696 / 702 correct 0.99
# graphene data acc:
# Got 3973 / 4141 correct 0.96
# Epoch 0, Iteration 23, loss = 1.1467
# Got 430 / 642 correct 0.67
# Got 1581 / 2246 correct 0.70
#
# Epoch 1, Iteration 46, loss = 0.5866
# Got 435 / 642 correct 0.68
# Got 1580 / 2246 correct 0.70
#
# Epoch 2, Iteration 69, loss = 0.6559
# Got 439 / 642 correct 0.68
# Got 1601 / 2246 correct 0.71
#
# Epoch 3, Iteration 92, loss = 0.5304
# Got 497 / 642 correct 0.77
# Got 1863 / 2246 correct 0.83
#
# Epoch 4, Iteration 115, loss = 0.4390
# Got 531 / 642 correct 0.83
# Got 1968 / 2246 correct 0.88
#
# Epoch 5, Iteration 138, loss = 0.1900
# Got 566 / 642 correct 0.88
# Got 2043 / 2246 correct 0.91
#
# Epoch 6, Iteration 161, loss = 0.1702
# Got 594 / 642 correct 0.93
# Got 2121 / 2246 correct 0.94
#
# Epoch 7, Iteration 184, loss = 0.1636
# Got 612 / 642 correct 0.95
# Got 2177 / 2246 correct 0.97
#
# Epoch 8, Iteration 207, loss = 0.0916
# Got 606 / 642 correct 0.94
# Got 2165 / 2246 correct 0.96
#
# Epoch 9, Iteration 230, loss = 0.0178
# Got 611 / 642 correct 0.95
# Got 2140 / 2246 correct 0.95
#
# Epoch 10, Iteration 253, loss = 0.0652
# Got 628 / 642 correct 0.98
# Got 2205 / 2246 correct 0.98
#
# Epoch 11, Iteration 276, loss = 0.2365
# Got 632 / 642 correct 0.98
# Got 2230 / 2246 correct 0.99
#
# Epoch 12, Iteration 299, loss = 0.0377
# Got 633 / 642 correct 0.99
# Got 2219 / 2246 correct 0.99
#
# Epoch 13, Iteration 322, loss = 0.0077
# Got 632 / 642 correct 0.98
# Got 2217 / 2246 correct 0.99
#
# Epoch 14, Iteration 345, loss = 0.0222
# Got 629 / 642 correct 0.98
# Got 2203 / 2246 correct 0.98
#
# Epoch 15, Iteration 368, loss = 0.0270
# Got 617 / 642 correct 0.96
# Got 2187 / 2246 correct 0.97
#
# Epoch 16, Iteration 391, loss = 0.0098
# Got 634 / 642 correct 0.99
# Got 2236 / 2246 correct 1.00
#
# Epoch 17, Iteration 414, loss = 0.0090
# Got 632 / 642 correct 0.98
# Got 2210 / 2246 correct 0.98
#
# Epoch 18, Iteration 437, loss = 0.0089
# Got 638 / 642 correct 0.99
# Got 2228 / 2246 correct 0.99
#
# Epoch 19, Iteration 460, loss = 0.0083
# Got 634 / 642 correct 0.99
# Got 2228 / 2246 correct 0.99
#
# Epoch 20, Iteration 483, loss = 0.0096
# Got 634 / 642 correct 0.99
# Got 2232 / 2246 correct 0.99
#
# Epoch 21, Iteration 506, loss = 0.0263
# Got 633 / 642 correct 0.99
# Got 2230 / 2246 correct 0.99
#
# Epoch 22, Iteration 529, loss = 0.0424
# Got 633 / 642 correct 0.99
# Got 2234 / 2246 correct 0.99
#
# lr decay from 0.001 to 0.0001
# 0.02 >= 0.01
# Epoch 23, Iteration 552, loss = 0.0028
# Got 638 / 642 correct 0.99
# Got 2241 / 2246 correct 1.00
#
# Epoch 24, Iteration 575, loss = 0.0021
# Got 637 / 642 correct 0.99
# Got 2244 / 2246 correct 1.00
#
# Epoch 25, Iteration 598, loss = 0.0016
# Got 638 / 642 correct 0.99
# Got 2245 / 2246 correct 1.00
#
# Epoch 26, Iteration 621, loss = 0.0134
# Got 638 / 642 correct 0.99
# Got 2244 / 2246 correct 1.00
#
# Epoch 27, Iteration 644, loss = 0.0030
# Got 638 / 642 correct 0.99
# Got 2245 / 2246 correct 1.00
#
# Epoch 28, Iteration 667, loss = 0.0184
# Got 639 / 642 correct 1.00
# Got 2245 / 2246 correct 1.00
#
# Epoch 29, Iteration 690, loss = 0.0015
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 30, Iteration 713, loss = 0.0093
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# lr decay from 0.0001 to 1e-05
# 0.01 >= 0.00
# Epoch 31, Iteration 736, loss = 0.0021
# Got 639 / 642 correct 1.00
# Got 2246 / 2246 correct 1.00
#
# Epoch 32, Iteration 759, loss = 0.0017
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 33, Iteration 782, loss = 0.0011
# Got 639 / 642 correct 1.00
# Got 2246 / 2246 correct 1.00
#
# Epoch 34, Iteration 805, loss = 0.0027
# Got 639 / 642 correct 1.00
# Got 2246 / 2246 correct 1.00
#
# Epoch 35, Iteration 828, loss = 0.0013
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 36, Iteration 851, loss = 0.0024
# Got 639 / 642 correct 1.00
# Got 2246 / 2246 correct 1.00
#
# Epoch 37, Iteration 874, loss = 0.0182
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# lr decay from 1e-05 to 1.0000000000000002e-06
# 0.01 >= 0.00
# Epoch 38, Iteration 897, loss = 0.0008
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 39, Iteration 920, loss = 0.0014
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 40, Iteration 943, loss = 0.0019
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 41, Iteration 966, loss = 0.0069
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 42, Iteration 989, loss = 0.0032
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 43, Iteration 1012, loss = 0.0040
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 44, Iteration 1035, loss = 0.0050
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 45, Iteration 1058, loss = 0.0019
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# lr decay from 1.0000000000000002e-06 to 1.0000000000000002e-07
# 0.00 >= 0.00
# Epoch 46, Iteration 1081, loss = 0.0021
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 47, Iteration 1104, loss = 0.0029
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 48, Iteration 1127, loss = 0.0019
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# Epoch 49, Iteration 1150, loss = 0.0015
# Got 638 / 642 correct 0.99
# Got 2246 / 2246 correct 1.00
#
# weight_decay:  0
# number of training: tensor(3208.)
# seen data acc:
# Got 320 / 320 correct 1.00
# unseen data acc:
# Got 797 / 802 correct 0.99
# graphene data acc:
# Got 3932 / 4141 correct 0.95
# Epoch 0, Iteration 26, loss = 0.9148
# Got 521 / 722 correct 0.72
# Got 1758 / 2526 correct 0.70
#
# Epoch 1, Iteration 52, loss = 0.7330
# Got 556 / 722 correct 0.77
# Got 1892 / 2526 correct 0.75
#
# Epoch 2, Iteration 78, loss = 0.3930
# Got 640 / 722 correct 0.89
# Got 2208 / 2526 correct 0.87
#
# Epoch 3, Iteration 104, loss = 0.3217
# Got 680 / 722 correct 0.94
# Got 2361 / 2526 correct 0.93
#
# Epoch 4, Iteration 130, loss = 0.8128
# Got 662 / 722 correct 0.92
# Got 2303 / 2526 correct 0.91
#
# Epoch 5, Iteration 156, loss = 0.1392
# Got 687 / 722 correct 0.95
# Got 2380 / 2526 correct 0.94
#
# Epoch 6, Iteration 182, loss = 0.1627
# Got 710 / 722 correct 0.98
# Got 2470 / 2526 correct 0.98
#
# Epoch 7, Iteration 208, loss = 0.0154
# Got 698 / 722 correct 0.97
# Got 2436 / 2526 correct 0.96
#
# Epoch 8, Iteration 234, loss = 0.0870
# Got 710 / 722 correct 0.98
# Got 2497 / 2526 correct 0.99
#
# Epoch 9, Iteration 260, loss = 0.0059
# Got 714 / 722 correct 0.99
# Got 2504 / 2526 correct 0.99
#
# Epoch 10, Iteration 286, loss = 0.0109
# Got 713 / 722 correct 0.99
# Got 2500 / 2526 correct 0.99
#
# Epoch 11, Iteration 312, loss = 0.1476
# Got 713 / 722 correct 0.99
# Got 2499 / 2526 correct 0.99
#
# Epoch 12, Iteration 338, loss = 0.0038
# Got 714 / 722 correct 0.99
# Got 2491 / 2526 correct 0.99
#
# Epoch 13, Iteration 364, loss = 0.0089
# Got 713 / 722 correct 0.99
# Got 2503 / 2526 correct 0.99
#
# Epoch 14, Iteration 390, loss = 0.0888
# Got 710 / 722 correct 0.98
# Got 2485 / 2526 correct 0.98
#
# lr decay from 0.001 to 0.0001
# 0.06 >= 0.03
# Epoch 15, Iteration 416, loss = 0.0135
# Got 719 / 722 correct 1.00
# Got 2515 / 2526 correct 1.00
#
# Epoch 16, Iteration 442, loss = 0.0018
# Got 719 / 722 correct 1.00
# Got 2521 / 2526 correct 1.00
#
# Epoch 17, Iteration 468, loss = 0.0124
# Got 721 / 722 correct 1.00
# Got 2521 / 2526 correct 1.00
#
# Epoch 18, Iteration 494, loss = 0.0031
# Got 721 / 722 correct 1.00
# Got 2523 / 2526 correct 1.00
#
# Epoch 19, Iteration 520, loss = 0.0026
# Got 721 / 722 correct 1.00
# Got 2524 / 2526 correct 1.00
#
# Epoch 20, Iteration 546, loss = 0.0096
# Got 720 / 722 correct 1.00
# Got 2525 / 2526 correct 1.00
#
# Epoch 21, Iteration 572, loss = 0.0028
# Got 719 / 722 correct 1.00
# Got 2523 / 2526 correct 1.00
#
# Epoch 22, Iteration 598, loss = 0.0132
# Got 721 / 722 correct 1.00
# Got 2523 / 2526 correct 1.00
#
# lr decay from 0.0001 to 1e-05
# 0.01 >= 0.01
# Epoch 23, Iteration 624, loss = 0.0034
# Got 720 / 722 correct 1.00
# Got 2525 / 2526 correct 1.00
#
# Epoch 24, Iteration 650, loss = 0.0047
# Got 720 / 722 correct 1.00
# Got 2525 / 2526 correct 1.00
#
# Epoch 25, Iteration 676, loss = 0.0007
# Got 720 / 722 correct 1.00
# Got 2525 / 2526 correct 1.00
#
# Epoch 26, Iteration 702, loss = 0.0082
# Got 720 / 722 correct 1.00
# Got 2525 / 2526 correct 1.00
#
# Epoch 27, Iteration 728, loss = 0.0081
# Got 720 / 722 correct 1.00
# Got 2525 / 2526 correct 1.00
#
# Epoch 28, Iteration 754, loss = 0.0046
# Got 720 / 722 correct 1.00
# Got 2525 / 2526 correct 1.00
#
# acc_val reachs to 100%, end the training loop
# weight_decay:  0
# number of training: tensor(3608.)
# seen data acc:
# Got 359 / 360 correct 1.00
# unseen data acc:
# Got 894 / 902 correct 0.99
# graphene data acc:
# Got 3851 / 4141 correct 0.93
# Epoch 0, Iteration 29, loss = 0.9351
# Got 537 / 802 correct 0.67
# Got 1960 / 2806 correct 0.70
#
# Epoch 1, Iteration 58, loss = 0.3007
# Got 572 / 802 correct 0.71
# Got 2068 / 2806 correct 0.74
#
# Epoch 2, Iteration 87, loss = 0.7152
# Got 576 / 802 correct 0.72
# Got 2078 / 2806 correct 0.74
#
# Epoch 3, Iteration 116, loss = 0.7051
# Got 589 / 802 correct 0.73
# Got 2161 / 2806 correct 0.77
#
# Epoch 4, Iteration 145, loss = 0.2767
# Got 659 / 802 correct 0.82
# Got 2372 / 2806 correct 0.85
#
# Epoch 5, Iteration 174, loss = 0.5102
# Got 664 / 802 correct 0.83
# Got 2389 / 2806 correct 0.85
#
# Epoch 6, Iteration 203, loss = 0.3473
# Got 729 / 802 correct 0.91
# Got 2588 / 2806 correct 0.92
#
# Epoch 7, Iteration 232, loss = 0.0285
# Got 711 / 802 correct 0.89
# Got 2521 / 2806 correct 0.90
#
# Epoch 8, Iteration 261, loss = 0.0470
# Got 782 / 802 correct 0.98
# Got 2731 / 2806 correct 0.97
#
# Epoch 9, Iteration 290, loss = 1.1971
# Got 771 / 802 correct 0.96
# Got 2716 / 2806 correct 0.97
#
# Epoch 10, Iteration 319, loss = 0.0182
# Got 778 / 802 correct 0.97
# Got 2760 / 2806 correct 0.98
#
# Epoch 11, Iteration 348, loss = 0.0005
# Got 792 / 802 correct 0.99
# Got 2786 / 2806 correct 0.99
#
# lr decay from 0.001 to 0.0001
# 0.32 >= 0.28
# Epoch 12, Iteration 377, loss = 0.1664
# Got 798 / 802 correct 1.00
# Got 2802 / 2806 correct 1.00
#
# Epoch 13, Iteration 406, loss = 0.0298
# Got 799 / 802 correct 1.00
# Got 2798 / 2806 correct 1.00
#
# Epoch 14, Iteration 435, loss = 0.0077
# Got 798 / 802 correct 1.00
# Got 2802 / 2806 correct 1.00
#
# Epoch 15, Iteration 464, loss = 0.0066
# Got 798 / 802 correct 1.00
# Got 2801 / 2806 correct 1.00
#
# Epoch 16, Iteration 493, loss = 0.0124
# Got 798 / 802 correct 1.00
# Got 2801 / 2806 correct 1.00
#
# Epoch 17, Iteration 522, loss = 0.0285
# Got 799 / 802 correct 1.00
# Got 2801 / 2806 correct 1.00
#
# Epoch 18, Iteration 551, loss = 0.0065
# Got 798 / 802 correct 1.00
# Got 2803 / 2806 correct 1.00
#
# Epoch 19, Iteration 580, loss = 0.0077
# Got 798 / 802 correct 1.00
# Got 2803 / 2806 correct 1.00
#
# Epoch 20, Iteration 609, loss = 0.0001
# Got 799 / 802 correct 1.00
# Got 2802 / 2806 correct 1.00
#
# Epoch 21, Iteration 638, loss = 0.0111
# Got 799 / 802 correct 1.00
# Got 2803 / 2806 correct 1.00
#
# Epoch 22, Iteration 667, loss = 0.0008
# Got 798 / 802 correct 1.00
# Got 2803 / 2806 correct 1.00
#
# Epoch 23, Iteration 696, loss = 0.0019
# Got 799 / 802 correct 1.00
# Got 2802 / 2806 correct 1.00
#
# Epoch 24, Iteration 725, loss = 0.0074
# Got 798 / 802 correct 1.00
# Got 2805 / 2806 correct 1.00
#
# Epoch 25, Iteration 754, loss = 0.0016
# Got 798 / 802 correct 1.00
# Got 2805 / 2806 correct 1.00
#
# Epoch 26, Iteration 783, loss = 0.0215
# Got 798 / 802 correct 1.00
# Got 2803 / 2806 correct 1.00
#
# lr decay from 0.0001 to 1e-05
# 0.01 >= 0.00
# Epoch 27, Iteration 812, loss = 0.0041
# Got 797 / 802 correct 0.99
# Got 2802 / 2806 correct 1.00
#
# Epoch 28, Iteration 841, loss = 0.0038
# Got 798 / 802 correct 1.00
# Got 2802 / 2806 correct 1.00
#
# acc_val reachs to 100%, end the training loop
# weight_decay:  0
# number of training: tensor(4008.)
# seen data acc:
# Got 399 / 400 correct 1.00
# unseen data acc:
# Got 993 / 1002 correct 0.99
# graphene data acc:
# Got 3920 / 4141 correct 0.95
# CPU times: user 33.6 s, sys: 570 ms, total: 34.2 s
# Wall time: 35.6 s

# %%
print(N_train)
# Out:
# tensor([ 408.,  808., 1208., 1608., 2008., 2408., 2808., 3208., 3608., 4008.])

# %%
import matplotlib.pyplot as plt
acc_test_error = torch.std(acc_test,dim=0)/stats
acc_test_unseen_error = torch.std(acc_test_unseen,dim=0)/stats
acc_graphene_error = torch.std(acc_graphene,dim=0)/stats
plt.subplot(1,1,1)
plt.plot(0.9*N_train,acc_test.mean(dim=0),'b')
plt.errorbar(0.9*N_train,acc_test.mean(dim=0),yerr=acc_test_error,fmt='bo',linewidth=1, capsize=4,markersize=4,markerfacecolor='white',label='(i)validation')
plt.plot(0.9*N_train,acc_test_unseen.mean(dim=0),'g')
plt.errorbar(0.9*N_train,acc_test_unseen.mean(dim=0),yerr=acc_test_unseen_error,fmt='gs',linewidth=1, capsize=4,markersize=4,markerfacecolor='white',label='(ii)validation')
plt.plot(0.9*N_train,acc_graphene.mean(dim=0),'r')
plt.errorbar(0.9*N_train,acc_graphene.mean(dim=0),yerr=acc_graphene_error,fmt='rv',linewidth=1, capsize=4,markersize=4,markerfacecolor='white',label='(iii)graphene')
plt.legend()
plt.xlabel('$N_{train}$')
plt.ylabel('Accuracy')
plt.savefig("Accuracy_function.svg")
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:1185: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:1186: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])

# %%
print(acc_graphene.mean(dim=0),acc_test_unseen.mean(dim=0),acc_test.mean(dim=0))
# Out:
# tensor([0.7206, 0.8823, 0.8841, 0.9343, 0.9317, 0.9456, 0.9389, 0.9439, 0.9478,
#         0.9475]) tensor([0.9201, 0.9465, 0.9604, 0.9791, 0.9679, 0.9922, 0.9907, 0.9888, 0.9920,
#         0.9917]) tensor([0.7237, 0.8531, 0.8958, 0.9272, 0.9300, 0.9860, 0.9887, 0.9905, 0.9911,
#         0.9879])

# %%
print(acc_graphene_density[:,-1].mean(dim=0))
# Out:
# tensor([1.0000, 1.0000, 1.0000, 0.9613, 0.6909, 0.9980, 0.9951, 0.9873, 0.9918,
#         0.9951, 0.6981, 0.9528, 1.0000, 1.0000, 1.0000])

# %%
figure = plt.figure(1,figsize=(10,2))
ax = plt.subplot(1,1,1)
bin_edges=torch.tensor([-5.0000, -4.3333, -3.6667, -3.0000, -2.3333, -1.6667, -1.0000, -0.3333,
         0.3333,  1.0000,  1.6667,  2.3333,  3.0000,  3.6667,  4.3333,  5.0000])
plt.hist(bin_edges[:-1],bin_edges,weights=acc_graphene_density[:,-1].mean(dim=0),rwidth=0.92)
# plt.plot(torch.linspace(-5,5,bins),acc_graphene_density[:,-1].mean(dim=0))
plt.plot(bin_edges[:-1]+1/3,acc_graphene_density[:,-1].mean(dim=0))
ax.xaxis.set_ticks(torch.linspace(-5,5,11))
plt.savefig("Accuracy_density.svg")

# %% [markdown]
# ## Set up dataset for training

# %%
D_total_off = (D_total.reshape(winding_u,mu_random,1,mu_steps,B_steps) + D_total.reshape(winding_u,1,mu_random,mu_steps,B_steps))**2
labels = (labels.reshape(winding_u,mu_random,1)+labels.reshape(winding_u,1,mu_random)).reshape(-1)
# D_total_off = D_total
# split dataset to training and unseen data
D_unseen = D_total_off[-2:].reshape(-1,1,mu_steps,B_steps) # the last two winding numbers as unseen data
D_train = D_total_off[:-2].reshape(-1,1,mu_steps,B_steps)
print(D_total_off.shape,D_train.shape,D_unseen.shape)
# Out:
# torch.Size([10, 501, 501, 15, 15]) torch.Size([2008008, 1, 15, 15]) torch.Size([502002, 1, 15, 15])

# %%
##############################################################
#set up dataset to train
##############################################################
from Superfluid_Neural_network_v2 import *
batch_size = 500
# set up labels 0-6 for training winding numbers, 7 for winding numbers above 6
labels[labels>6] = 7
labels = labels.long()
num_class = 8
#construct dataset
dataset = Superfluid_Dataset(D_train,labels[:(winding_u-2)*mu_random**2],train=True) # train the model with the train data
dataset_unseen = Superfluid_Dataset(D_unseen,labels[(winding_u-2)*mu_random**2:],train=True)

# split the dataset to train, validation, test
train_set, valid_set,test_set = torch.utils.data.random_split(dataset, [0.7,0.2,0.1])

#Using Dataloader for batch train
train_loader = torch.utils.data.DataLoader(dataset=train_set,batch_size=batch_size,shuffle=True)
valid_loader = torch.utils.data.DataLoader(dataset=valid_set,batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_set,batch_size=batch_size,shuffle=True)
test_loader_unseen = torch.utils.data.DataLoader(dataset=dataset_unseen,batch_size=batch_size,shuffle=True)

# %%
from Superfluid_Neural_network_v2 import *
CNN_stages = [(1,32,1),(32,2,1)]
fc_stages = [(CNN_stages[-1][1]*B_steps*mu_steps,1024,1),(1024,512,1)]
my_vgg = NN_net(CNN_stages,fc_stages,Plain_CNN_block,Plain_fc_block,num_classes=num_class)
#my_vgg.apply(weight_init)
print(my_vgg)
# Out:
# NN_net(
#   (total_net): Sequential(
#     (0): NN_stages(
#       (net): Sequential(
#         (0): Plain_CNN_block(
#           (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (relu): ReLU()
#         )
#       )
#     )
#     (1): NN_stages(
#       (net): Sequential(
#         (0): Plain_CNN_block(
#           (conv1): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (relu): ReLU()
#         )
#       )
#     )
#     (2): NN_stages(
#       (net): Sequential(
#         (0): Plain_fc_block(
#           (fc): Linear(in_features=450, out_features=1024, bias=True)
#           (relu): ReLU()
#         )
#       )
#     )
#     (3): NN_stages(
#       (net): Sequential(
#         (0): Plain_fc_block(
#           (fc): Linear(in_features=1024, out_features=512, bias=True)
#           (relu): ReLU()
#         )
#       )
#     )
#     (4): Linear(in_features=512, out_features=8, bias=True)
#   )
# )

# %% [markdown]
# ## Train the model

# %%
import random
from Training_loops import *
# optimizer parameters
epochs = 30
learning_rate_decay = .1
schedule = [10,25,40,45]
learning_rates = [1e-3]
weight_decays = [0]
acc_dict = {}
num_taskes = 2
for learning_rate in learning_rates:
  for weight_decay in weight_decays:
    my_vgg.apply(weight_init)
    L1_weight_decay = 0
    optimizer = torch.optim.Adam([{'params':my_vgg.parameters()}],lr=learning_rate,weight_decay=weight_decay)

    acc_history,acc_val_history,loss_history,iter_history = train_part(model=my_vgg,optimizer=optimizer,
    train_loader=train_loader,valid_loader=valid_loader,epochs=epochs,learning_rate_decay=learning_rate_decay,schedule=schedule,weight_decay=L1_weight_decay,verbose=False)
    ##############################################################
    print('weight_decay: ',weight_decay)
    print('seen data acc: ')
    acc_test= check_accuary(test_loader,my_vgg)
    print('unseen data acc:')
    acc_test_unseen = check_accuary(test_loader_unseen,my_vgg)
# Out:
# Epoch 0, Iteration 2812, loss = 0.1382
# Got 378364 / 401602 correct 0.94
# Got 1323653 / 1405606 correct 0.94
#
# Epoch 1, Iteration 5624, loss = 0.2540
# Got 388580 / 401602 correct 0.97
# Got 1359897 / 1405606 correct 0.97
#
# Epoch 2, Iteration 8436, loss = 0.0226
# Got 398080 / 401602 correct 0.99
# Got 1393746 / 1405606 correct 0.99
#
# Epoch 3, Iteration 11248, loss = 0.0056
# Got 398011 / 401602 correct 0.99
# Got 1393473 / 1405606 correct 0.99
#
# Epoch 4, Iteration 14060, loss = 0.1203
# Got 393174 / 401602 correct 0.98
# Got 1376092 / 1405606 correct 0.98
#
# Epoch 5, Iteration 16872, loss = 0.0064
# Got 398398 / 401602 correct 0.99
# Got 1394438 / 1405606 correct 0.99
#
# Epoch 6, Iteration 19684, loss = 0.0314
# Got 399318 / 401602 correct 0.99
# Got 1397791 / 1405606 correct 0.99
#
# Epoch 7, Iteration 22496, loss = 0.0131
# Got 399616 / 401602 correct 1.00
# Got 1398738 / 1405606 correct 1.00
#
# Epoch 8, Iteration 25308, loss = 0.0595
# Got 399269 / 401602 correct 0.99
# Got 1397662 / 1405606 correct 0.99
#
# Epoch 9, Iteration 28120, loss = 0.0048
# Got 399639 / 401602 correct 1.00
# Got 1398869 / 1405606 correct 1.00
#
# Epoch 10, Iteration 30932, loss = 0.0033
# Got 400006 / 401602 correct 1.00
# Got 1400345 / 1405606 correct 1.00
#
# Epoch 11, Iteration 33744, loss = 0.0062
# Got 399949 / 401602 correct 1.00
# Got 1400020 / 1405606 correct 1.00
#
# Epoch 12, Iteration 36556, loss = 0.0002
# Got 400252 / 401602 correct 1.00
# Got 1401056 / 1405606 correct 1.00
#
# Epoch 13, Iteration 39368, loss = 0.0211
# Got 400042 / 401602 correct 1.00
# Got 1400231 / 1405606 correct 1.00
#
# Epoch 14, Iteration 42180, loss = 0.0005
# Got 399960 / 401602 correct 1.00
# Got 1399955 / 1405606 correct 1.00
#
# Epoch 15, Iteration 44992, loss = 0.0097
# Got 400651 / 401602 correct 1.00
# Got 1402391 / 1405606 correct 1.00
#
# Epoch 16, Iteration 47804, loss = 0.0014
# Got 400205 / 401602 correct 1.00
# Got 1400943 / 1405606 correct 1.00
#
# lr decay from 0.001 to 0.0001
# 0.01 >= 0.00
# Epoch 17, Iteration 50616, loss = 0.0079
# Got 401328 / 401602 correct 1.00
# Got 1404849 / 1405606 correct 1.00
#
# Epoch 18, Iteration 53428, loss = 0.0008
# Got 401318 / 401602 correct 1.00
# Got 1404741 / 1405606 correct 1.00
#
# Epoch 19, Iteration 56240, loss = 0.0004
# Got 401283 / 401602 correct 1.00
# Got 1404695 / 1405606 correct 1.00
#
# Epoch 20, Iteration 59052, loss = 0.0000
# Got 401315 / 401602 correct 1.00
# Got 1404772 / 1405606 correct 1.00
#
# Epoch 21, Iteration 61864, loss = 0.0001
# Got 401363 / 401602 correct 1.00
# Got 1404973 / 1405606 correct 1.00
#
# Epoch 22, Iteration 64676, loss = 0.0001
# Got 401319 / 401602 correct 1.00
# Got 1404755 / 1405606 correct 1.00
#
# Epoch 23, Iteration 67488, loss = 0.0000
# Got 401385 / 401602 correct 1.00
# Got 1404990 / 1405606 correct 1.00
#
# Epoch 24, Iteration 70300, loss = 0.0000
# Got 401430 / 401602 correct 1.00
# Got 1405167 / 1405606 correct 1.00
#
# Epoch 25, Iteration 73112, loss = 0.0004
# Got 401420 / 401602 correct 1.00
# Got 1405087 / 1405606 correct 1.00
#
# Epoch 26, Iteration 75924, loss = 0.0000
# Got 401394 / 401602 correct 1.00
# Got 1405056 / 1405606 correct 1.00
#
# Epoch 27, Iteration 78736, loss = 0.0078
# Got 401349 / 401602 correct 1.00
# Got 1404912 / 1405606 correct 1.00
#
# lr decay from 0.0001 to 1e-05
# 0.00 >= 0.00
# acc_val reachs to 100%, end the training loop
# weight_decay:  0
# seen data acc:
# Got 200690 / 200800 correct 1.00
# unseen data acc:
# Got 501410 / 502002 correct 1.00

# %%
print("Model's state_dict: ")
for param_tensor in my_vgg.state_dict():
  print(param_tensor,"\t",my_vgg.state_dict()[param_tensor])
# Out:
# Model's state_dict:
# params 	 tensor([0.7687, 1.0139])

# %%
my_vgg_path = os.path.join(GOOGLE_DRIVE_PATH,'my_vgg_path_broken.pt')
torch.save(my_vgg.state_dict(),my_vgg_path)

# %%
my_vgg_path = os.path.join(GOOGLE_DRIVE_PATH,'my_vgg_path_broken.pt')
my_vgg.load_state_dict(torch.load(my_vgg_path))
my_vgg.to('cuda')
my_vgg.eval()
# Out:
# NN_net(
#   (total_net): Sequential(
#     (0): NN_stages(
#       (net): Sequential(
#         (0): Plain_CNN_block(
#           (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (relu): ReLU()
#         )
#       )
#     )
#     (1): NN_stages(
#       (net): Sequential(
#         (0): Plain_CNN_block(
#           (conv1): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (relu): ReLU()
#         )
#       )
#     )
#     (2): NN_stages(
#       (net): Sequential(
#         (0): Plain_fc_block(
#           (fc): Linear(in_features=450, out_features=1024, bias=True)
#           (relu): ReLU()
#         )
#       )
#     )
#     (3): NN_stages(
#       (net): Sequential(
#         (0): Plain_fc_block(
#           (fc): Linear(in_features=1024, out_features=512, bias=True)
#           (relu): ReLU()
#         )
#       )
#     )
#     (4): Linear(in_features=512, out_features=8, bias=True)
#   )
# )

# %% [markdown]
# ## Plot accuracy results

# %%
import matplotlib.pyplot as plt
import numpy as np
ave_site = 5
ave_kernel = 1/ave_site*np.ones(ave_site)
loss_history_conv = np.convolve(loss_history.numpy(),ave_kernel,'same')
plt.title('Train and Val accuracies')
plt.plot(iter_history,acc_history,'-o')
plt.plot(iter_history,acc_val_history,'-o')
plt.legend(['train acc','val acc'])
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.show()
plt.title('loss')
plt.plot(iter_history,loss_history,'-o')
plt.plot(iter_history,loss_history_conv,'-*')
plt.legend(['loss','loss_conv'])
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# ## Check acc with graphene data

# %%
Graphene_D_xx_path = os.path.join(GOOGLE_DRIVE_PATH,'Graphene_D_xx_broken.pt')
Graphene_D_yy_path = os.path.join(GOOGLE_DRIVE_PATH,'Graphene_D_yy_broken.pt')
Graphene_label_path = os.path.join(GOOGLE_DRIVE_PATH,'Graphene_label_broken.pt')
Graphene_D_xx = torch.load(Graphene_D_xx_path)
Graphene_D_yy = torch.load(Graphene_D_yy_path)
Graphene_labels = torch.load(Graphene_label_path)
t_size = 21
mu_size = 101
print(Graphene_D_xx.shape)
print(Graphene_D_xx.reshape(21,101,15,15)[20,50,7,7])
Graphene_D_broken = ((Graphene_D_xx.reshape(t_size,mu_size,1,mu_steps,B_steps) + Graphene_D_xx.reshape(t_size,1,mu_size,mu_steps,B_steps))*(Graphene_D_yy.reshape(t_size,mu_size,1,mu_steps,B_steps) + Graphene_D_yy.reshape(t_size,1,mu_size,mu_steps,B_steps))).reshape(-1,1,mu_steps,B_steps)
Graphene_labels_broken = (Graphene_labels.reshape(t_size,mu_size,1)+Graphene_labels.reshape(t_size,1,mu_size)).reshape(-1)
# Out:
# torch.Size([2121, 1, 15, 15])
# tensor(1.0519)

# %%
print('max:',Graphene_D_broken.max(),'min:',Graphene_D_broken.min())
# Out:
# max: tensor(55.4846) min: tensor(0.0002)

# %%
from Training_loops import *
batch_size = 50
print(Graphene_D_broken.shape)
Graphene_Data = Superfluid_Dataset(Graphene_D_broken,Graphene_labels_broken,train=True)
Graphene_loader = torch.utils.data.DataLoader(dataset=Graphene_Data,batch_size=batch_size,shuffle=True)
acc_Graphene= check_accuary(Graphene_loader,my_vgg,verbose=True)
# Out:
# torch.Size([214221, 1, 15, 15])
# Got 199667 / 214221 correct 0.93
# Got 71208 / 214221 correct 0.33 preds as 0
# Got 34931 / 214221 correct 0.16 preds as 2
# Got 2186 / 214221 wrong 0.01 preds as 0
# Got 4762 / 214221 wrong 0.02 preds as 1
# Got 7606 / 214221 wrong 0.04 preds as 2
# Got 0 / 214221 wrong 0.00 preds as 3
# Got 0 / 214221 wrong 0.00 preds as 4
# Got 0 / 214221 wrong 0.00 preds as 5
# Got 0 / 214221 wrong 0.00 preds as 6
# Got 0 / 214221 wrong 0.00 preds as larger than 6

# %%
from collections import Counter
broken_counts = Counter(Graphene_labels_broken.tolist())
counts = Counter(Graphene_labels.tolist())
print(broken_counts,counts)
# Out:
# Counter({1.0: 103320, 0.0: 75600, 2.0: 35301}) Counter({0.0: 1260, 1.0: 861})

# %%
import matplotlib.pyplot as plt
Graphene_D_test = Graphene_D_broken.reshape(t_size,mu_size,mu_size,mu_steps,B_steps)
vmax = torch.max(Graphene_D_test).item()
vmin = torch.min(Graphene_D_test).item()
fig,ax = plt.subplots(1,3)
fig.set_figwidth(27)
fig.set_figheight(9)
# ax[0].imshow(Graphene_D_test[0,50,50],vmax=vmax,vmin=vmin)
# ax[1].imshow(Graphene_D_test[1,50,50],vmax=vmax,vmin=vmin)
# im=ax[2].imshow(Graphene_D_test[2,50,50],vmax=vmax,vmin=vmin)
ax[0].imshow(Graphene_D_test[0,50,0])
ax[1].imshow(Graphene_D_test[1,50,0])
im=ax[2].imshow(Graphene_D_test[2,50,0])
plt.colorbar(im,ax=ax)

# %%
scorce = my_vgg(Graphene_D_test[20,50,0].reshape(1,1,15,15).to('cuda'))
preds = torch.argmax(scorce,dim=1)
print(preds)
scorce = my_vgg(Graphene_D_test_a[1,250,0].reshape(1,1,15,15).to('cuda'))
preds = torch.argmax(scorce,dim=1)
print(preds)
# Out:
# tensor([2], device='cuda:0')
# tensor([1], device='cuda:0')

# %%
import matplotlib.pyplot as plt
Graphene_D_test_a = D_total_off.reshape(winding_u,mu_random,mu_random,mu_steps,B_steps)
vmax = torch.max(Graphene_D_test_a).item()
vmin = torch.min(Graphene_D_test_a).item()
fig,ax = plt.subplots(1,1)
fig.set_figwidth(27)
fig.set_figheight(9)
im=ax.imshow(Graphene_D_test_a[1,250,0])
plt.colorbar(im,ax=ax)

# %% [markdown]
# # Fully connected neural network

# %%
from Superfluid_Neural_network import *
#my_fc = threelayers_fc_block(in_neurals=B_steps,med_neurals=1024,out_neurals=1)
my_fc = torch.nn.Sequential(
    torch.nn.Linear(B_steps,512,bias=True),
    torch.nn.ReLU(),
    torch.nn.Linear(512,1024,bias=True),
    torch.nn.ReLU(),
    torch.nn.Linear(1024,512,bias=True),
    torch.nn.ReLU(),
    torch.nn.Linear(512,1,bias=True)
)
my_fc.apply(weight_init)
# Out:
# Sequential(
#   (0): Linear(in_features=100, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=512, out_features=1024, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=1024, out_features=512, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=512, out_features=1, bias=True)
# )
